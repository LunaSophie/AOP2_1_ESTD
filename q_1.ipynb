# %%
#   self= para que os atributos e métodos que vc definiu sejam acessíveis dentro do método 
#(não é obrigatório).
#   __init__ : método construtor de uma classe
#   "->" serve para fazer link com um outro dado string
#   __repr__: retorna a representação de string do objeto ou classe. Diferente do __str__, pois retorna
#informações mais ricas ou oficial, retorna uma expressão válida python que pode ser usado para recriar
#o objeto
#   Dunder method: métodos que permite que as instancias de uma classe interaja com funções padrões
#e operador de linguagem. (double underscore "__")
#   Built-in function: função padrão (que já veio com a linguagem de programa, aplicação ou outras 
#ferramentas).

import pandas as pd
from datetime import datetime

dataframe=pd.DataFrame()
mediaPorDia = []

#   Pegar dados dos clientes:
class Cliente:
    def __init__(self, nome, valorDaConta):
        self.nome = nome
        self.valorDaConta = valorDaConta

class Nodo:
    def __init__(self, dado=0, proximo= None):
        self.dado = dado
        self.proximo = proximoNodo

    def __repr__ (self):
        return f' {self.dado} -> {self.proximo}'
   
    def setProximo(self, proximoNodo):
        self.proximo= proximoNodo


    def __repr__(self):
        return f'{self.nome} -> {self.valorDaConta}'

class ListaSimplesmenteEncadeada:
    def __init__(self):
        self.head = None
        self.tamanhoDaLista = 0
    
    def insere(self, novoDado):
        novoNodo = Nodo(novoDado)
        novoNodo.proximo = self.head
        self.head = novoNodo
        self.tamanhoDaLista += 1
        
    def delete(self):
        if self.head == None:
            print('A lista já esta vazia')
        
        else:
            self.head = self.head.proximo
            self.tamanhoDaLista -= 1
    
    def close(self):

#Ao fechar o dia irá ativar as funções abaixo 
#Somar todos os valores do valorDaConta da lista do dia.
#Somar a quantidade de cliente/comanda do dia
#Colocar numa tabela data, n de comanda, valorMedio/dia 
class valorMedioCliente:
    def __init__(self, valorTotal) -> None:
        pass

mediaPorDia = []
mediaPorDia.append(datetime.now())
mediaPorDia.append(n_cliente)
mediaPorDia.append(valorMedioCliente)

#Criar a tabela media
tabela_media = pd.DataFrame(data=mediaPorDia, columns=['Data','N de Cliente','Valor Médio/dia'])
print(tabela_media)
